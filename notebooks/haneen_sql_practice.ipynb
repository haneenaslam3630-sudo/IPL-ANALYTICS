# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect(r'C:\Users\h1n2e\Downloads\Project_3.1\data\raw\ipl.db')
def q(sql):
    return pd.read_sql_query(sql, conn)

# %%
q("""select* from venues;""")
# Out:
#     venue_id                                              venue  \
# 0          1                              M Chinnaswamy Stadium
# 1          2          Rajiv Gandhi International Stadium, Uppal
# 2          3            Maharashtra Cricket Association Stadium
# 3          4             Saurashtra Cricket Association Stadium
# 4          5                             Holkar Cricket Stadium
# ..       ...                                                ...
# 58        59                         Subrata Roy Sahara Stadium
# 59        60   Shaheed Veer Narayan Singh International Stadium
# 60        61                 JSCA International Stadium Complex
# 61        62  Maharaja Yadavindra Singh International Cricke...
# 62        63  Maharaja Yadavindra Singh International Cricke...
#
#               city
# 0        Bangalore
# 1        Hyderabad
# 2             Pune
# 3           Rajkot
# 4           Indore
# ..             ...
# 58            Pune
# 59          Raipur
# ...

# %%
q("""select* from matches;""")
# Out:
#       match_id  season_id  balls_per_over            city  match_date  \
# 0       335982       2008               6       Bangalore  2008-04-18
# 1      1082591       2017               6       Hyderabad  2017-04-05
# 2      1082592       2017               6            Pune  2017-04-06
# 3      1082593       2017               6          Rajkot  2017-04-07
# 4      1082594       2017               6          Indore  2017-04-08
# ...        ...        ...             ...             ...         ...
# 1207   1529282       2026               6           Delhi  2026-04-27
# 1208   1529283       2026               6  New Chandigarh  2026-04-28
# 1209   1529284       2026               6          Mumbai  2026-04-29
# 1210   1529285       2026               6       Ahmedabad  2026-04-30
# 1211   1529286       2026               6          Jaipur  2026-05-01
#
#                  event_name  match_number gender match_type format  ...  \
# ...

# %%
q("""select * from players;""")
# Out:
#      player_id    player_name       bat_style  \
# 0          963     MN Samuels  Right hand Bat
# 1           53      SB Jakati   Left hand Bat
# 2           12      DA Warner   Left hand Bat
# 3          268    RA Tripathi  Right hand Bat
# 4          186       S Nadeem  Right hand Bat
# ..         ...            ...             ...
# 794       8475  Suyash Sharma  Right hand Bat
# 795      45004   D Madushanka  Right hand Bat
# 796      42566  V Suryavanshi   Left hand Bat
# 797         26         N Rana   Left hand Bat
# 798      45986      SU Parakh   Left hand Bat
#
#                                          bowl_style field_pos  \
# 0                                Right arm Offbreak
# 1                            Slow Left arm Orthodox
# 2                                          Legbreak
# 3                                  Right arm Medium
# 4                            Slow Left arm Orthodox
# ..                                              ...       ...
# ...

# %%
q("""select * from deliveries;""")
# Out:
#         season_id  match_id           batter          bowler      non_striker  \
# 0            2008    335982       SC Ganguly         P Kumar      BB McCullum
# 1            2008    335982      BB McCullum         P Kumar       SC Ganguly
# 2            2008    335982      BB McCullum         P Kumar       SC Ganguly
# 3            2008    335982      BB McCullum         P Kumar       SC Ganguly
# 4            2008    335982      BB McCullum         P Kumar       SC Ganguly
# ...           ...       ...              ...             ...              ...
# 288221       2026   1529286         T Stubbs       JC Archer  Ashutosh Sharma
# 288222       2026   1529286  Ashutosh Sharma       JC Archer         T Stubbs
# 288223       2026   1529286         T Stubbs       JC Archer  Ashutosh Sharma
# 288224       2026   1529286  Ashutosh Sharma  Brijesh Sharma         T Stubbs
# 288225       2026   1529286  Ashutosh Sharma  Brijesh Sharma         T Stubbs
#
# ...

# %%
q("""select * from teams;""")
# Out:
#     team_id                    team_name
# 0         1  Royal Challengers Bangalore
# 1         2          Sunrisers Hyderabad
# 2         3               Mumbai Indians
# 3         4       Rising Pune Supergiant
# 4         5                Gujarat Lions
# 5         6        Kolkata Knight Riders
# 6       129          Chennai Super Kings
# 7       134             Rajasthan Royals
# 8       252               Delhi Capitals
# 9       494                 Punjab Kings
# 10      614         Lucknow Super Giants
# 11      615               Gujarat Titans
# 12     1068              Deccan Chargers
# 13     1414         Kochi Tuskers Kerala
# 14     1419                Pune Warriors
# 15     3604      Rising Pune Supergiants

# %%
q("""select * from matches limit 15;""")
# Out:
#     match_id  season_id  balls_per_over       city  match_date  \
# 0     335982       2008               6  Bangalore  2008-04-18
# 1    1082591       2017               6  Hyderabad  2017-04-05
# 2    1082592       2017               6       Pune  2017-04-06
# 3    1082593       2017               6     Rajkot  2017-04-07
# 4    1082594       2017               6     Indore  2017-04-08
# 5    1082595       2017               6  Bengaluru  2017-04-08
# 6    1082596       2017               6  Hyderabad  2017-04-09
# 7    1082597       2017               6     Mumbai  2017-04-09
# 8    1082598       2017               6     Indore  2017-04-10
# 9    1082599       2017               6       Pune  2017-04-11
# 10   1082600       2017               6     Mumbai  2017-04-12
# 11   1082601       2017               6    Kolkata  2017-04-13
# 12   1082602       2017               6  Bangalore  2017-04-14
# 13   1082603       2017               6     Rajkot  2017-04-14
# ...

# %%
q("""select match_id,city,venue from matches limit 15;""")
# Out:
#     match_id       city                                      venue
# 0     335982  Bangalore                      M Chinnaswamy Stadium
# 1    1082591  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 2    1082592       Pune    Maharashtra Cricket Association Stadium
# 3    1082593     Rajkot     Saurashtra Cricket Association Stadium
# 4    1082594     Indore                     Holkar Cricket Stadium
# 5    1082595  Bengaluru                      M.Chinnaswamy Stadium
# 6    1082596  Hyderabad  Rajiv Gandhi International Stadium, Uppal
# 7    1082597     Mumbai                           Wankhede Stadium
# 8    1082598     Indore                     Holkar Cricket Stadium
# 9    1082599       Pune    Maharashtra Cricket Association Stadium
# 10   1082600     Mumbai                           Wankhede Stadium
# 11   1082601    Kolkata                               Eden Gardens
# 12   1082602  Bangalore                      M Chinnaswamy Stadium
# ...

# %%
q("""select season_id,match_id,batter,bowler from deliveries limit 15;""")
# Out:
#     season_id  match_id       batter   bowler
# 0        2008    335982   SC Ganguly  P Kumar
# 1        2008    335982  BB McCullum  P Kumar
# 2        2008    335982  BB McCullum  P Kumar
# 3        2008    335982  BB McCullum  P Kumar
# 4        2008    335982  BB McCullum  P Kumar
# 5        2008    335982  BB McCullum  P Kumar
# 6        2008    335982  BB McCullum  P Kumar
# 7        2008    335982  BB McCullum   Z Khan
# 8        2008    335982  BB McCullum   Z Khan
# 9        2008    335982  BB McCullum   Z Khan
# 10       2008    335982  BB McCullum   Z Khan
# 11       2008    335982  BB McCullum   Z Khan
# 12       2008    335982  BB McCullum   Z Khan
# 13       2008    335982   SC Ganguly  P Kumar
# 14       2008    335982   SC Ganguly  P Kumar

# %%
q("""select DISTINCT batsman_type from deliveries;""")
# Out:
#      batsman_type
# 0   Left hand Bat
# 1  Right hand Bat
# 2             NaN

# %%
q("""select DISTINCT bowler_type from deliveries;""")
# Out:
#                                        bowler_type
# 0                                 Right arm Medium
# 1                             Left arm Fast medium
# 2                            Right arm Fast medium
# 3                           Slow Left arm Orthodox
# 4                                  Legbreak Googly
# 5                            Right arm Medium fast
# 6                                   Right arm Fast
# 7                                    Left arm Fast
# 8                                  Left arm Medium
# 9                             Left arm Medium fast
# 10                              Right arm Offbreak
# 11                                        Legbreak
# 12                             Left arm Wrist spin
# 13  Right arm Medium, Right arm Offbreak, Legbreak
# 14                    Right arm Offbreak, Legbreak
# 15             Right arm Offbreak, Legbreak Googly
# 16            Right arm Medium, Right arm Offbreak
# ...

# %%
q("""select DISTINCT season_id from matches;""")
# Out:
#     season_id
# 0        2008
# 1        2017
# 2        2018
# 3        2019
# 4        2020
# 5        2021
# 6        2022
# 7        2023
# 8        2024
# 9        2025
# 10       2009
# 11       2010
# 12       2011
# 13       2012
# 14       2013
# 15       2014
# 16       2015
# 17       2016
# 18       2026

# %%
q("""select DISTINCT bowl_style from players;""")
# Out:
#                                         bowl_style
# 0                               Right arm Offbreak
# 1                           Slow Left arm Orthodox
# 2                                         Legbreak
# 3                                 Right arm Medium
# 4                                  Legbreak Googly
# 5                            Right arm Medium fast
# 6
# 7                                   Right arm Fast
# 8                              Left arm Wrist spin
# 9                             Left arm Medium fast
# 10                            Left arm Fast medium
# 11                           Right arm Fast medium
# 12     Slow Left arm Orthodox, Left arm Wrist spin
# 13                                   Left arm Fast
# 14                           Right arm Fast Medium
# 15                                 Left arm Medium
# 16                                Right arm Bowler
# 17                                             NaN
# ...

# %%
q("""select match_id,season_id,city,match_winner FROM matches where match_winner = 'Chennai Super Kings';""")
# Out:
#      match_id  season_id       city         match_winner
# 0     1136561       2018     Mumbai  Chennai Super Kings
# 1     1136565       2018    Chennai  Chennai Super Kings
# 2     1136577       2018       Pune  Chennai Super Kings
# 3     1136580       2018  Hyderabad  Chennai Super Kings
# 4     1136584       2018  Bengaluru  Chennai Super Kings
# ..        ...        ...        ...                  ...
# 141   1473494       2025    Kolkata  Chennai Super Kings
# 142   1473504       2025  Ahmedabad  Chennai Super Kings
# 143   1527691       2026    Chennai  Chennai Super Kings
# 144   1529265       2026    Chennai  Chennai Super Kings
# 145   1529276       2026     Mumbai  Chennai Super Kings
#
# [146 rows x 4 columns]

# %%
q("""select match_id, season, city,venue
FROM matches
WHERE SEASON >= 2015 OR CITY = 'Chennai';""")
# Out:
#      match_id season            city  \
# 0     1082591   2017       Hyderabad
# 1     1082592   2017            Pune
# 2     1082593   2017          Rajkot
# 3     1082594   2017          Indore
# 4     1082595   2017       Bengaluru
# ..        ...    ...             ...
# 790   1529282   2026           Delhi
# 791   1529283   2026  New Chandigarh
# 792   1529284   2026          Mumbai
# 793   1529285   2026       Ahmedabad
# 794   1529286   2026          Jaipur
#
#                                                  venue
# 0            Rajiv Gandhi International Stadium, Uppal
# 1              Maharashtra Cricket Association Stadium
# 2               Saurashtra Cricket Association Stadium
# 3                               Holkar Cricket Stadium
# 4                                M.Chinnaswamy Stadium
# ..                                                 ...
# 790                        Arun Jaitley Stadium, Delhi
# 791  Maharaja Yadavindra Singh International Cricke...
# ...

# %%
q("""select match_id, season, city,venue
FROM matches
WHERE SEASON >= 2015 AND CITY = 'Chennai';""")
# Out:
#     match_id season     city                                     venue
# 0     829707   2015  Chennai           MA Chidambaram Stadium, Chepauk
# 1     829711   2015  Chennai           MA Chidambaram Stadium, Chepauk
# 2     829753   2015  Chennai           MA Chidambaram Stadium, Chepauk
# 3     829765   2015  Chennai           MA Chidambaram Stadium, Chepauk
# 4     829779   2015  Chennai           MA Chidambaram Stadium, Chepauk
# 5     829789   2015  Chennai           MA Chidambaram Stadium, Chepauk
# 6     829797   2015  Chennai           MA Chidambaram Stadium, Chepauk
# 7    1136565   2018  Chennai                    MA Chidambaram Stadium
# 8    1175356   2019  Chennai                    MA Chidambaram Stadium
# 9    1175367   2019  Chennai                    MA Chidambaram Stadium
# 10   1178393   2019  Chennai                    MA Chidambaram Stadium
# 11   1178398   2019  Chennai                    MA Chidambaram Stadium
# ...

# %%
q("""select match_id, season,match_winner,venue
FROM matches
WHERE SEASON >= 2010 AND match_winner = 'Royal Challengers Bangalore';""")
# Out:
#      match_id season                 match_winner  \
# 0      419112   2010  Royal Challengers Bangalore
# 1      419115   2010  Royal Challengers Bangalore
# 2      419119   2010  Royal Challengers Bangalore
# 3      419123   2010  Royal Challengers Bangalore
# 4      419136   2010  Royal Challengers Bangalore
# ..        ...    ...                          ...
# 121   1527684   2026  Royal Challengers Bangalore
# 122   1527693   2026  Royal Challengers Bangalore
# 123   1529266   2026  Royal Challengers Bangalore
# 124   1529277   2026  Royal Challengers Bangalore
# 125   1529282   2026  Royal Challengers Bangalore
#
#                                           venue
# 0                         M Chinnaswamy Stadium
# 1                         M Chinnaswamy Stadium
# 2                             Brabourne Stadium
# 3                         M Chinnaswamy Stadium
# 4    Punjab Cricket Association Stadium, Mohali
# ..                                          ...
# ...

# %%
q("""select match_id,season,city,venue
FROM matches
WHERE SEASON >= 2010 OR match_winner = 'Bangalore'
ORDER BY match_id DESC;""")
# Out:
#       match_id season            city  \
# 0      1529286   2026          Jaipur
# 1      1529285   2026       Ahmedabad
# 2      1529284   2026          Mumbai
# 3      1529283   2026  New Chandigarh
# 4      1529282   2026           Delhi
# ...        ...    ...             ...
# 1092    419110   2010         Chennai
# 1093    419109   2010         Kolkata
# 1094    419108   2010      Chandigarh
# 1095    419107   2010          Mumbai
# 1096    419106   2010          Mumbai
#
#                                                   venue
# 0                        Sawai Mansingh Stadium, Jaipur
# 1                      Narendra Modi Stadium, Ahmedabad
# 2                              Wankhede Stadium, Mumbai
# 3     Maharaja Yadavindra Singh International Cricke...
# 4                           Arun Jaitley Stadium, Delhi
# ...                                                 ...
# 1092                    MA Chidambaram Stadium, Chepauk
# ...

# %%
q("""select match_id,season,city,venue
FROM matches
WHERE SEASON >= 2010 OR match_winner = 'Bangalore'
ORDER BY match_id ASC;""")
# Out:
#       match_id season            city  \
# 0       419106   2010          Mumbai
# 1       419107   2010          Mumbai
# 2       419108   2010      Chandigarh
# 3       419109   2010         Kolkata
# 4       419110   2010         Chennai
# ...        ...    ...             ...
# 1092   1529282   2026           Delhi
# 1093   1529283   2026  New Chandigarh
# 1094   1529284   2026          Mumbai
# 1095   1529285   2026       Ahmedabad
# 1096   1529286   2026          Jaipur
#
#                                                   venue
# 0                            Dr DY Patil Sports Academy
# 1                                     Brabourne Stadium
# 2            Punjab Cricket Association Stadium, Mohali
# 3                                          Eden Gardens
# 4                       MA Chidambaram Stadium, Chepauk
# ...                                                 ...
# 1092                        Arun Jaitley Stadium, Delhi
# ...

# %%
q("""select count(*) as matches
from matches;""")
# Out:
#    matches
# 0     1212

# %%
q("""select count(*) as deliveries
from Deliveries;""")
# Out:
#    deliveries
# 0      288226

# %%
q("""select count(*) as players
from players;""")
# Out:
#    players
# 0      799

# %%
q("""select count(*) as teams
from teams;""")
# Out:
#    teams
# 0     16

# %%
q("""select count(*) as venues
from venues;""")
# Out:
#    venues
# 0      63

# %%
q("""SELECT venue,count(*) as matches
from matches
group by venue;""")
# Out:
#                                                 venue  matches
# 0                                Arun Jaitley Stadium       14
# 1                         Arun Jaitley Stadium, Delhi       27
# 2                                    Barabati Stadium        7
# 3                 Barsapara Cricket Stadium, Guwahati        8
# 4   Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...       26
# 5                                   Brabourne Stadium       10
# 6                           Brabourne Stadium, Mumbai       17
# 7                                        Buffalo Park        3
# 8                               De Beers Diamond Oval        3
# 9                          Dr DY Patil Sports Academy       17
# 10                 Dr DY Patil Sports Academy, Mumbai       20
# 11  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...       13
# 12  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...        4
# 13                Dubai International Cricket Stadium       46
# ...

# %%
q("""SELECT match_winner,count(*) as winner
from matches
group by match_winner
order by winner desc;""")
# Out:
#                    match_winner  winner
# 0                Mumbai Indians     155
# 1           Chennai Super Kings     146
# 2   Royal Challengers Bangalore     139
# 3         Kolkata Knight Riders     137
# 4           Sunrisers Hyderabad     132
# 5                  Punjab Kings     130
# 6                Delhi Capitals     126
# 7              Rajasthan Royals     125
# 8                Gujarat Titans      42
# 9          Lucknow Super Giants      33
# 10       Rising Pune Supergiant      15
# 11                Pune Warriors      13
# 12                Gujarat Lions      13
# 13         Kochi Tuskers Kerala       6

# %%
q("""SELECT match_winner,count(*) as winner
from matches
group by match_winner
having count (*)>100
order by winner desc;""")
# Out:
#                   match_winner  winner
# 0               Mumbai Indians     155
# 1          Chennai Super Kings     146
# 2  Royal Challengers Bangalore     139
# 3        Kolkata Knight Riders     137
# 4          Sunrisers Hyderabad     132
# 5                 Punjab Kings     130
# 6               Delhi Capitals     126
# 7             Rajasthan Royals     125

# %%
q("""SELECT bowler,count(*) as balls
from deliveries
group by bowler
having count (*)>=1000
order by balls desc;""")
# Out:
#           bowler  balls
# 0       R Ashwin   4868
# 1        B Kumar   4596
# 2      SP Narine   4586
# 3      RA Jadeja   4261
# 4      YS Chahal   4068
# ..           ...    ...
# 81      VR Aaron   1065
# 82    GJ Maxwell   1047
# 83  JR Hazlewood   1035
# 84    Noor Ahmad   1008
# 85       S Gopal   1000
#
# [86 rows x 2 columns]

# %%
q("""SELECT count(*) as nullvalues
FROM matches
WHERE city is null;""")
# Out:
#    nullvalues
# 0          51

# %%
q("""SELECT count(*) as nullvalues
FROM matches
WHERE city is not null;""")
# Out:
#    nullvalues
# 0        1161

# %%
q("""SELECT count(*) as nullvalues
FROM matches
WHERE win_by_runs is not null;""")
# Out:
#    nullvalues
# 0         546

# %%
q("""SELECT match_winner,count(*) as win_by_runs
FROM matches
WHERE win_by_runs is NOT NULL
GROUP BY match_winner""")
# Out:
#                    match_winner  win_by_runs
# 0           Chennai Super Kings           75
# 1                Delhi Capitals           47
# 2                 Gujarat Lions            1
# 3                Gujarat Titans           16
# 4          Kochi Tuskers Kerala            2
# 5         Kolkata Knight Riders           57
# 6          Lucknow Super Giants           20
# 7                Mumbai Indians           77
# 8                 Pune Warriors            6
# 9                  Punjab Kings           57
# 10             Rajasthan Royals           48
# 11       Rising Pune Supergiant            7
# 12  Royal Challengers Bangalore           64
# 13          Sunrisers Hyderabad           69

# %%
q("""select trim   ('        virat kholi rcb       ');""")
# Out:
#   trim   ('        virat kholi rcb       ')
# 0                           virat kholi rcb

# %%
q("""SELECT batter,bowler,is_wicket
FROM deliveries
WHERE is_wicket=1""")
# Out:
#            batter        bowler  is_wicket
# 0      SC Ganguly        Z Khan          1
# 1      RT Ponting     JH Kallis          1
# 2       DJ Hussey     AA Noffke          1
# 3        R Dravid      I Sharma          1
# 4         V Kohli      AB Dinda          1
# ...           ...           ...        ...
# 14335     R Parag      MA Starc          1
# 14336    SB Dubey   T Natarajan          1
# 14337  P Nissanka     RA Jadeja          1
# 14338      N Rana  TU Deshpande          1
# 14339    KL Rahul     JC Archer          1
#
# [14340 rows x 3 columns]

# %%
q("""select lower(batter)
from deliveries;""")
# Out:
#          lower(batter)
# 0       a ashish reddy
# 1       a ashish reddy
# 2       a ashish reddy
# 3       a ashish reddy
# 4       a ashish reddy
# ...                ...
# 288221          z khan
# 288222          z khan
# 288223          z khan
# 288224          z khan
# 288225          z khan
#
# [288226 rows x 1 columns]

# %%
q("""select city, length(city)
from venues;""")
# Out:
#               city  length(city)
# 0        Bangalore           9.0
# 1        Hyderabad           9.0
# 2             Pune           4.0
# 3           Rajkot           6.0
# 4           Indore           6.0
# ..             ...           ...
# 58            Pune           4.0
# 59          Raipur           6.0
# 60          Ranchi           6.0
# 61  New Chandigarh          14.0
# 62  New Chandigarh          14.0
#
# [63 rows x 2 columns]

# %%
q("""select match_winner,
case when win_by_runs is null
then 'win by wickets'
else 'win by runs'
end as winning_type
from matches;""")
# Out:
#                      match_winner    winning_type
# 0           Kolkata Knight Riders     win by runs
# 1             Sunrisers Hyderabad     win by runs
# 2          Rising Pune Supergiant  win by wickets
# 3           Kolkata Knight Riders  win by wickets
# 4                    Punjab Kings  win by wickets
# ...                           ...             ...
# 1207  Royal Challengers Bangalore  win by wickets
# 1208             Rajasthan Royals  win by wickets
# 1209          Sunrisers Hyderabad  win by wickets
# 1210               Gujarat Titans  win by wickets
# 1211               Delhi Capitals  win by wickets
#
# [1212 rows x 2 columns]

# %%
q("""select venue,count(*) as matchs
from matches
group by venue;""")
# Out:
#                                                 venue  matchs
# 0                                Arun Jaitley Stadium      14
# 1                         Arun Jaitley Stadium, Delhi      27
# 2                                    Barabati Stadium       7
# 3                 Barsapara Cricket Stadium, Guwahati       8
# 4   Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...      26
# 5                                   Brabourne Stadium      10
# 6                           Brabourne Stadium, Mumbai      17
# 7                                        Buffalo Park       3
# 8                               De Beers Diamond Oval       3
# 9                          Dr DY Patil Sports Academy      17
# 10                 Dr DY Patil Sports Academy, Mumbai      20
# 11  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...      13
# 12  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...       4
# 13                Dubai International Cricket Stadium      46
# ...

# %%
q("""select venue,count(*) as matchs
from matches
where venue='Buffalo Park'
group by venue;""")
# Out:
#           venue  matchs
# 0  Buffalo Park       3

# %%
q("""select venue,count(*) as matchs
from matches
where venue='Buffalo Park'or venue='Eden Gardens'
group by venue;""")
# Out:
#           venue  matchs
# 0  Buffalo Park       3
# 1  Eden Gardens      77

# %%
q("""select batter,count(*) as delivery
from deliveries
group by batter
order by delivery desc;""")
# Out:
#              batter  delivery
# 0           V Kohli      6942
# 1         RG Sharma      5561
# 2          S Dhawan      5483
# 3         DA Warner      4849
# 4         AM Rahane      4259
# ..              ...       ...
# 722     Sunny Gupta         1
# 723          U Kaul         1
# 724  V Pratap Singh         1
# 725   Y Prithvi Raj         1
# 726      YA Abdulla         1
#
# [727 rows x 2 columns]

# %%
q("""select match_winner,
case when win_by_runs>50
then'high runs'
else 'low run'
end as runs
from matches;""")
# Out:
#                      match_winner       runs
# 0           Kolkata Knight Riders  high runs
# 1             Sunrisers Hyderabad    low run
# 2          Rising Pune Supergiant    low run
# 3           Kolkata Knight Riders    low run
# 4                    Punjab Kings    low run
# ...                           ...        ...
# 1207  Royal Challengers Bangalore    low run
# 1208             Rajasthan Royals    low run
# 1209          Sunrisers Hyderabad    low run
# 1210               Gujarat Titans    low run
# 1211               Delhi Capitals    low run
#
# [1212 rows x 2 columns]

# %%
q("""select m.match_id,m.venue
from matches m;""")
# Out:
#       match_id                                              venue
# 0       335982                              M Chinnaswamy Stadium
# 1      1082591          Rajiv Gandhi International Stadium, Uppal
# 2      1082592            Maharashtra Cricket Association Stadium
# 3      1082593             Saurashtra Cricket Association Stadium
# 4      1082594                             Holkar Cricket Stadium
# ...        ...                                                ...
# 1207   1529282                        Arun Jaitley Stadium, Delhi
# 1208   1529283  Maharaja Yadavindra Singh International Cricke...
# 1209   1529284                           Wankhede Stadium, Mumbai
# 1210   1529285                   Narendra Modi Stadium, Ahmedabad
# 1211   1529286                     Sawai Mansingh Stadium, Jaipur
#
# [1212 rows x 2 columns]

# %%
q("""select m.match_id,m.venue,v.city
from matches m
join venues v on m.venue=v.venue
limit 10;""")
# Out:
#    match_id                                      venue       city
# 0    335982                      M Chinnaswamy Stadium  Bangalore
# 1   1082591  Rajiv Gandhi International Stadium, Uppal  Hyderabad
# 2   1082592    Maharashtra Cricket Association Stadium       Pune
# 3   1082593     Saurashtra Cricket Association Stadium     Rajkot
# 4   1082594                     Holkar Cricket Stadium     Indore
# 5   1082595                      M.Chinnaswamy Stadium  Bengaluru
# 6   1082596  Rajiv Gandhi International Stadium, Uppal  Hyderabad
# 7   1082597                           Wankhede Stadium     Mumbai
# 8   1082598                     Holkar Cricket Stadium     Indore
# 9   1082599    Maharashtra Cricket Association Stadium       Pune

# %%
q("""select d.batter,p.bat_style
from deliveries as d
join players as p on p.player_name=d.batter;""")
# Out:
#             batter       bat_style
# 0       MN Samuels  Right hand Bat
# 1       MN Samuels  Right hand Bat
# 2       MN Samuels  Right hand Bat
# 3       MN Samuels  Right hand Bat
# 4       MN Samuels  Right hand Bat
# ...            ...             ...
# 288221      N Rana   Left hand Bat
# 288222      N Rana   Left hand Bat
# 288223      N Rana   Left hand Bat
# 288224   SU Parakh   Left hand Bat
# 288225   SU Parakh   Left hand Bat
#
# [288226 rows x 2 columns]

# %%
q("""select venue
from venues
except
select distinct venue
from matches;""")
# Out:
# Empty DataFrame
# Columns: [venue]
# Index: []

# %%
q("""select match_id,innings,over_number,ball_number,count(*)as n
from deliveries
group by match_id,innings,over_number,ball_number
having count(*)>1;""")
# Out:
# Empty DataFrame
# Columns: [match_id, innings, over_number, ball_number, n]
# Index: []

# %%
q("""select count(distinct batter)

from deliveries
where batter not in (select player_name from players);""")
# Out:
#    count(distinct batter)
# 0                       0

# %%
q("""select count(*) as total,
sum(case when city is null then 1 else 0 end) as missing
from matches;""")
# Out:
#    total  missing
# 0   1212       51

# %%
q("""select count(*) as total,
sum(case when city is null then 1 else 0 end) as missing
from venues;""")
# Out:
#    total  missing
# 0     63        2

# %%
q("""select count(*) as total,
sum(case when city is null then 1 else 0 end) as a_null,
sum(case when city = '' then 1 else 0 end) as empty,
sum(case when trim(city) = ''and city<>'' then 1 else 0 end)as spaces
from matches;""")
# Out:
#    total  a_null  empty  spaces
# 0   1212      51      0       0

# %%
q("""select count (distinct
case when instr(venue,',')>0
then trim(substr(venue,1,instr(venue,',')-1))
else trim (venue)end) as after_coma
from matches;""")
# Out:
#    after_coma
# 0          42

# %%
q("""select count(*)as row,
count (distinct venue ) as distinct_venues
from venues;""")
# Out:
#    row  distinct_venues
# 0   63               59

# %%
q("""select venue,count(*) as n
from venues
group by venue 
having count(*)>1""")
# Out:
#                                                venue  n
# 0                 Dr DY Patil Sports Academy, Mumbai  2
# 1                Dubai International Cricket Stadium  2
# 2  Maharaja Yadavindra Singh International Cricke...  2
# 3                            Sharjah Cricket Stadium  2

# %%
q("""select team_name,
(select count(*) 
from matches m
where m.team1=t.team_name or m.team2=t.team_name) as played
from teams t
order by team_name;""")
# Out:
#                       team_name  played
# 0           Chennai Super Kings     260
# 1               Deccan Chargers       0
# 2                Delhi Capitals     276
# 3                 Gujarat Lions      30
# 4                Gujarat Titans      69
# 5          Kochi Tuskers Kerala      14
# 6         Kolkata Knight Riders     272
# 7          Lucknow Super Giants      66
# 8                Mumbai Indians     285
# 9                 Pune Warriors      46
# 10                 Punjab Kings     272
# 11             Rajasthan Royals     245
# 12       Rising Pune Supergiant      30
# 13      Rising Pune Supergiants       0
# 14  Royal Challengers Bangalore     279
# 15          Sunrisers Hyderabad     280

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect(r'C:\Users\h1n2e\Downloads\Project_3.1\data\raw\ipl.db')

pd.read_sql_query("""
select result,count(*) as n
from matches
group by result;
""", conn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 q("""select result,count(*)as n
#       2 from matches
#       3 group by result;""")
#
# NameError: name 'q' is not defined
